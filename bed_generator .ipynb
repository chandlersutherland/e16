# %%
import os 
import pandas as pd
import sys
import glob

# %%
#import the gene table, which has the NLRs for all accessions 
gene_table='/global/home/users/chandlersutherland/e16/Maize_NLRome_GeneTable.txt'

# %%
#glob all the gff3 files across all genomes 
gff3_files=glob.glob('/global/scratch/users/chandlersutherland/e16/*/genome/*1.gff3')
gff3_files
# Out:
# ['/global/scratch/users/chandlersutherland/e16/B97/genome/Zm-B97-REFERENCE-NAM-1.0_Zm00018ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/Oh43/genome/Zm-Oh43-REFERENCE-NAM-1.0_Zm00039ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/Tx303/genome/Zm-Tx303-REFERENCE-NAM-1.0_Zm00041ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/CML69/genome/Zm-CML69-REFERENCE-NAM-1.0_Zm00020ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/CML333/genome/Zm-CML333-REFERENCE-NAM-1.0_Zm00026ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/NC358/genome/Zm-NC358-REFERENCE-NAM-1.0_Zm00037ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/NC350/genome/Zm-NC350-REFERENCE-NAM-1.0_Zm00036ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/Mo18W/genome/Zm-Mo18W-REFERENCE-NAM-1.0_Zm00034ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/CML103/genome/Zm-CML103-REFERENCE-NAM-1.0_Zm00021ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/CML247/genome/Zm-CML247-REFERENCE-NAM-1.0_Zm00023ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/B73/genome/Zm-B73-REFERENCE-NAM-5.0_Zm00001eb.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/CML228/genome/Zm-CML228-REFERENCE-NAM-1.0_Zm00022ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/P39/genome/Zm-P39-REFERENCE-NAM-1.0_Zm00040ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/Oh7B/genome/Zm-Oh7B-REFERENCE-NAM-1.0_Zm00038ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/MS71/genome/Zm-Ms71-REFERENCE-NAM-1.0_Zm00035ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/IL14H/genome/Zm-Il14H-REFERENCE-NAM-1.0_Zm00028ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/Ki11/genome/Zm-Ki11-REFERENCE-NAM-1.0_Zm00030ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/CML52/genome/Zm-CML52-REFERENCE-NAM-1.0_Zm00019ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/CML322/genome/Zm-CML322-REFERENCE-NAM-1.0_Zm00025ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/KY21/genome/Zm-Ky21-REFERENCE-NAM-1.0_Zm00031ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/M37W/genome/Zm-M37W-REFERENCE-NAM-1.0_Zm00032ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/Tzi8/genome/Zm-Tzi8-REFERENCE-NAM-1.0_Zm00042ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/M162W/genome/Zm-M162W-REFERENCE-NAM-1.0_Zm00033ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/HP301/genome/Zm-HP301-REFERENCE-NAM-1.0_Zm00027ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/CML277/genome/Zm-CML277-REFERENCE-NAM-1.0_Zm00024ab.1.gff3',
#  '/global/scratch/users/chandlersutherland/e16/Ki3/genome/Zm-Ki3-REFERENCE-NAM-1.0_Zm00029ab.1.gff3']

# %%
b73='/global/scratch/users/chandlersutherland/e16/B73/genome/Zm-B73-REFERENCE-NAM-5.0_Zm00001eb.1.gff3'
gff3=pd.read_csv(b73, sep='\t', skiprows=3, header=0, lineterminator='\n')
gff3=gff3.reset_index()
gff3=gff3.rename(columns={gff3.columns[0]:'chr', gff3.columns[1]:'source', gff3.columns[2]:'sequence_ontology', gff3.columns[3]:'start', gff3.columns[4]:'end', gff3.columns[5]:'score', gff3.columns[6]:'strand', gff3.columns[7]:'phase', gff3.columns[8]:'attributes'})
gff3
# Out:
#               chr    source sequence_ontology  start        end score strand  \
# 0            chr1  assembly        chromosome      1  308452471     .      .
# 1            chr1       NAM              gene  34617      40204     .      +
# 2            chr1       NAM              mRNA  34617      40204     .      +
# 3            chr1       NAM    five_prime_UTR  34617      34721     .      +
# 4            chr1       NAM              exon  34617      35318     .      +
# ...           ...       ...               ...    ...        ...   ...    ...
# 1143798  scaf_695       NAM              mRNA   2336       4226     .      -
# 1143799  scaf_695       NAM    five_prime_UTR   4218       4226     .      -
# 1143800  scaf_695       NAM              exon   2336       4226     .      -
# 1143801  scaf_695       NAM               CDS   2898       4217     .      -
# 1143802  scaf_695       NAM   three_prime_UTR   2336       2897     .      -
#
#         phase                                         attributes
# 0           .  ID=1;Name=chromosome:Zm-B73-REFERENCE-NAM-5.0:...
# 1           .  ID=Zm00001eb000010;biotype=protein_coding;logi...
# 2           .  ID=Zm00001eb000010_T001;Parent=Zm00001eb000010...
# 3           .                        Parent=Zm00001eb000010_T001
# 4           .  Parent=Zm00001eb000010_T001;Name=Zm00001eb0000...
# ...       ...                                                ...
# 1143798     .  ID=Zm00001eb443030_T001;Parent=Zm00001eb443030...
# 1143799     .                        Parent=Zm00001eb443030_T001
# 1143800     .  Parent=Zm00001eb443030_T001;Name=Zm00001eb4430...
# 1143801     0  ID=Zm00001eb443030_P001;Parent=Zm00001eb443030...
# 1143802     .                        Parent=Zm00001eb443030_T001
#
# [1143803 rows x 9 columns]

# %%
genes=gff3[gff3['sequence_ontology']=='gene']
genes['attributes'].str.split(';', expand=True)[2].unique()
# Out:
# array(['logic_name=cshl_gene'], dtype=object)

# %%
#define a function that takes a gff3 file path as input, and outputs an all gene bed file and an NLR specific bed file. 
def bed_generator(gff_filepath, gene_table):
    #read in and cleanup gff3 file 
    gff3=pd.read_csv(gff_filepath, sep='\t', skiprows=3, header=0, lineterminator='\n')
    gff3=gff3.reset_index()
    gff3=gff3.rename(columns={gff3.columns[0]:'chr', gff3.columns[1]:'source', gff3.columns[2]:'sequence_ontology', gff3.columns[3]:'start', gff3.columns[4]:'end', gff3.columns[5]:'score', gff3.columns[6]:'strand', gff3.columns[7]:'phase', gff3.columns[8]:'attributes'})

    #get metadata
    accession=gff_filepath.split('/')[6]
    basename=gff_filepath.split('/')[8].split('.')[0]
    print(accession+ ' gff3 file loaded')
    
    #filter gff3 to just genes, and expand attributes  
    genes = gff3[gff3['sequence_ontology'] == 'gene']
    attributes=genes.iloc[:,8].str.split(';',expand=True)
    genes.loc[:,'ID']=attributes.iloc[:,0].str.split('=', expand=True)[1]
    genes.loc[:,'biotype']=attributes.iloc[:,1].str.split('=', expand=True)[1]
    genes.loc[:,'logic_name']=attributes.iloc[:,2].str.split('=', expand=True)[1]
    
    #generate a bed file for all genes 
    bed = genes.loc[:,['chr', 'start', 'end', 'ID', 'strand']]
    bed = bed.rename(columns={'chr':'chrom', 'start':'chromStart', 'end':'chromEnd', 'ID':'name', 'strand':'strand'})
    bed.to_csv('/global/scratch/users/chandlersutherland/e16/' + accession + '/genome/' + basename + '_all_gene.bed', sep='\t')
    print('all gene bed written to '+'/global/scratch/users/chandlersutherland/e16/' + accession + '/genome/' + basename + '_all_gene.bed')
    
    #Load NLR gene names
    gene=pd.read_csv(gene_table,sep = '\t')
    nlr_df=gene[gene['Ecotype'] == accession.lower()]
    nlrs=nlr_df.loc[:,'Gene'].str.split('_', expand=True).iloc[:,0].str.replace('ZM', 'Zm').str.replace('AB', 'ab').str.replace('EB','eb').unique()
    
    #quality stats 
    match=bed['name'].isin(nlrs).sum()
    unmatch=len(nlrs)-match 
    print(str(match)+' NLRs found in gff file for '+accession+'. We are missing '+str(unmatch)+'.')
    
    #write out NLR bed file
    nlr_bed=bed[bed['name'].isin(nlrs)]
    nlr_bed.to_csv('/global/scratch/users/chandlersutherland/e16/' + accession + '/genome/' + basename + '_NLR.bed', sep='\t')
    print('NLR bed written to '+'/global/scratch/users/chandlersutherland/e16/' + accession + '/genome/' + basename + '_NLR.bed')

# %%
for i in gff3_files:
    bed_generator(str(i), gene_table)
# Out:
# B97 gff3 file loaded
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# all gene bed written to /global/scratch/users/chandlersutherland/e16/B97/genome/Zm-B97-REFERENCE-NAM-1_all_gene.bed
# 125 NLRs found in gff file for B97. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/B97/genome/Zm-B97-REFERENCE-NAM-1_NLR.bed
# Oh43 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/Oh43/genome/Zm-Oh43-REFERENCE-NAM-1_all_gene.bed
# 131 NLRs found in gff file for Oh43. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/Oh43/genome/Zm-Oh43-REFERENCE-NAM-1_NLR.bed
# Tx303 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/Tx303/genome/Zm-Tx303-REFERENCE-NAM-1_all_gene.bed
# 121 NLRs found in gff file for Tx303. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/Tx303/genome/Zm-Tx303-REFERENCE-NAM-1_NLR.bed
# CML69 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/CML69/genome/Zm-CML69-REFERENCE-NAM-1_all_gene.bed
# 133 NLRs found in gff file for CML69. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/CML69/genome/Zm-CML69-REFERENCE-NAM-1_NLR.bed
# CML333 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/CML333/genome/Zm-CML333-REFERENCE-NAM-1_all_gene.bed
# 131 NLRs found in gff file for CML333. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/CML333/genome/Zm-CML333-REFERENCE-NAM-1_NLR.bed
# NC358 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/NC358/genome/Zm-NC358-REFERENCE-NAM-1_all_gene.bed
# 132 NLRs found in gff file for NC358. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/NC358/genome/Zm-NC358-REFERENCE-NAM-1_NLR.bed
# NC350 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/NC350/genome/Zm-NC350-REFERENCE-NAM-1_all_gene.bed
# 136 NLRs found in gff file for NC350. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/NC350/genome/Zm-NC350-REFERENCE-NAM-1_NLR.bed
# Mo18W gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/Mo18W/genome/Zm-Mo18W-REFERENCE-NAM-1_all_gene.bed
# 117 NLRs found in gff file for Mo18W. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/Mo18W/genome/Zm-Mo18W-REFERENCE-NAM-1_NLR.bed
# CML103 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/CML103/genome/Zm-CML103-REFERENCE-NAM-1_all_gene.bed
# 119 NLRs found in gff file for CML103. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/CML103/genome/Zm-CML103-REFERENCE-NAM-1_NLR.bed
# CML247 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/CML247/genome/Zm-CML247-REFERENCE-NAM-1_all_gene.bed
# 114 NLRs found in gff file for CML247. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/CML247/genome/Zm-CML247-REFERENCE-NAM-1_NLR.bed
# B73 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/B73/genome/Zm-B73-REFERENCE-NAM-5_all_gene.bed
# 0 NLRs found in gff file for B73. We are missing 126.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/B73/genome/Zm-B73-REFERENCE-NAM-5_NLR.bed
# CML228 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/CML228/genome/Zm-CML228-REFERENCE-NAM-1_all_gene.bed
# 126 NLRs found in gff file for CML228. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/CML228/genome/Zm-CML228-REFERENCE-NAM-1_NLR.bed
# P39 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/P39/genome/Zm-P39-REFERENCE-NAM-1_all_gene.bed
# 118 NLRs found in gff file for P39. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/P39/genome/Zm-P39-REFERENCE-NAM-1_NLR.bed
# Oh7B gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/Oh7B/genome/Zm-Oh7B-REFERENCE-NAM-1_all_gene.bed
# 121 NLRs found in gff file for Oh7B. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/Oh7B/genome/Zm-Oh7B-REFERENCE-NAM-1_NLR.bed
# MS71 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/MS71/genome/Zm-Ms71-REFERENCE-NAM-1_all_gene.bed
# 122 NLRs found in gff file for MS71. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/MS71/genome/Zm-Ms71-REFERENCE-NAM-1_NLR.bed
# IL14H gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/IL14H/genome/Zm-Il14H-REFERENCE-NAM-1_all_gene.bed
# 125 NLRs found in gff file for IL14H. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/IL14H/genome/Zm-Il14H-REFERENCE-NAM-1_NLR.bed
# Ki11 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/Ki11/genome/Zm-Ki11-REFERENCE-NAM-1_all_gene.bed
# 120 NLRs found in gff file for Ki11. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/Ki11/genome/Zm-Ki11-REFERENCE-NAM-1_NLR.bed
# CML52 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/CML52/genome/Zm-CML52-REFERENCE-NAM-1_all_gene.bed
# 130 NLRs found in gff file for CML52. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/CML52/genome/Zm-CML52-REFERENCE-NAM-1_NLR.bed
# CML322 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/CML322/genome/Zm-CML322-REFERENCE-NAM-1_all_gene.bed
# 121 NLRs found in gff file for CML322. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/CML322/genome/Zm-CML322-REFERENCE-NAM-1_NLR.bed
# KY21 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/KY21/genome/Zm-Ky21-REFERENCE-NAM-1_all_gene.bed
# 126 NLRs found in gff file for KY21. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/KY21/genome/Zm-Ky21-REFERENCE-NAM-1_NLR.bed
# M37W gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/M37W/genome/Zm-M37W-REFERENCE-NAM-1_all_gene.bed
# 134 NLRs found in gff file for M37W. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/M37W/genome/Zm-M37W-REFERENCE-NAM-1_NLR.bed
# Tzi8 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/Tzi8/genome/Zm-Tzi8-REFERENCE-NAM-1_all_gene.bed
# 130 NLRs found in gff file for Tzi8. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/Tzi8/genome/Zm-Tzi8-REFERENCE-NAM-1_NLR.bed
# M162W gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/M162W/genome/Zm-M162W-REFERENCE-NAM-1_all_gene.bed
# 122 NLRs found in gff file for M162W. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/M162W/genome/Zm-M162W-REFERENCE-NAM-1_NLR.bed
# HP301 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/HP301/genome/Zm-HP301-REFERENCE-NAM-1_all_gene.bed
# 116 NLRs found in gff file for HP301. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/HP301/genome/Zm-HP301-REFERENCE-NAM-1_NLR.bed
# CML277 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/CML277/genome/Zm-CML277-REFERENCE-NAM-1_all_gene.bed
# 126 NLRs found in gff file for CML277. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/CML277/genome/Zm-CML277-REFERENCE-NAM-1_NLR.bed
# Ki3 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/Ki3/genome/Zm-Ki3-REFERENCE-NAM-1_all_gene.bed
# 129 NLRs found in gff file for Ki3. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/Ki3/genome/Zm-Ki3-REFERENCE-NAM-1_NLR.bed

# %%
bed_generator(gff3_files[10], gene_table)
# Out:
# B73 gff3 file loaded
# all gene bed written to /global/scratch/users/chandlersutherland/e16/B73/genome/Zm-B73-REFERENCE-NAM-5_all_gene.bed
# 126 NLRs found in gff file for B73. We are missing 0.
# NLR bed written to /global/scratch/users/chandlersutherland/e16/B73/genome/Zm-B73-REFERENCE-NAM-5_NLR.bed
